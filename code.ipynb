# %%
import pandas as pd 

df = pd.read_csv("../ProjetLlms/full_graph_updated.csv")

df.head(100)
# Out:
#     _id   _labels                          name  _start  _end         _type  \
# 0   0.0  :Concept        n_gram_language_models     NaN   NaN           NaN
# 1   1.0  :Concept          linear_approximation     NaN   NaN           NaN
# 2   2.0  :Concept             linear_regression     NaN   NaN           NaN
# 3   3.0  :Concept                        vector     NaN   NaN           NaN
# 4   4.0  :Concept  independent_random_variables     NaN   NaN           NaN
# ..  ...       ...                           ...     ...   ...           ...
# 95  NaN       NaN                           NaN    14.0   5.0  PREREQUISITE
# 96  NaN       NaN                           NaN    14.0  10.0  PREREQUISITE
# 97  NaN       NaN                           NaN    14.0  24.0  PREREQUISITE
# 98  NaN       NaN                           NaN    15.0  30.0  PREREQUISITE
# 99  NaN       NaN                           NaN    16.0   4.0  PREREQUISITE
#
#     known
# 0       0
# 1       0
# 2       0
# ...
